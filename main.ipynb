# %%
import pandas as pd

df = pd.read_parquet("artifacts/master_dataset/latest/master_dataset.parquet")

# %%
df.head(5)
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104      553718                              Hearing Care Provider
# 1  3757940025     2192142  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019      474443                               Manager, Engineering
# 3  3757938018    18213359                                               Cook
# 4  3757937095      437225        Principal Cloud Security Architect (Remote)
#
#                                          description          location  views  \
# 0  Overview HearingLife is a national hearing car...  Little River, SC      9
# 1  Metalcraft of Mayville Metalcraft of Mayville ...    Beaver Dam, WI   <NA>
# 2  The TSUBAKI name is synonymous with excellence...      Bessemer, AL   <NA>
# 3  descriptionTitle Looking for a great opportuni...   Aliso Viejo, CA      1
# 4  Job Summary At iHerb, we are on a mission to m...     United States   <NA>
#
# ...

# %%
len(df.columns.tolist())
# Out:
# 64

# %%
df.shape
# Out:
# (154676, 64)

# %%
cols = df.columns.unique().tolist()
cols
# Out:
# ['job_id',
#  'company_id',
#  'title',
#  'description',
#  'location',
#  'views',
#  'applies',
#  'min_salary',
#  'med_salary',
#  'max_salary',
#  'pay_period',
#  'currency',
#  'compensation_type',
#  'normalized_salary',
#  'formatted_work_type',
#  'work_type',
#  'remote_allowed',
#  'formatted_experience_level',
#  'listed_time',
#  'original_listed_time',
#  'expiry',
#  'closed_time',
#  'sponsored',
#  'zip_code',
#  'fips',
#  'unmapped__job_posting_url',
#  'unmapped__application_url',
#  'unmapped__application_type',
#  'unmapped__skills_desc',
#  'unmapped__posting_domain',
#  'unmapped__scraped',
#  'company_name',
#  'company_description',
#  'company_size',
#  'company_state',
#  'company_country',
#  'company_city',
#  'company_zip_code',
#  'company_address',
#  'company_url',
#  'company_employee_count',
#  'company_follower_count',
#  'company_employee_count_recorded_at',
#  'salary_id',
#  'listed_max_salary',
#  'listed_med_salary',
# ...
